# %% [markdown]
# ## LAB 3: Design and Analysis of Algorithms
# Name: Rudra Shah <br>
# Roll Number: 21BCM054
# ##### Q3. Design and analysis algorithms for merge sort. Elements can be read from a file or can be generated using random number generator. Determine time required to sort the elements. Repeat experiment for different values of n and plot the graph of the time taken versus n.

# %% [markdown]
# ##### Import Library

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import random
import time

# %%
def mergesort(arr):
    if len(arr) > 1:
        mid = len(arr)//2
        L = arr[:mid]
        R = arr[mid:]
        mergesort(L)
        mergesort(R)
        i = j = k = 0
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1
        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1
        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1

# %% [markdown]
# ## FOR RANDOM NUMBER

# %%
tt = []
for i in range(100,1000):
    rangeLim = i
    best = [random.randint(1,rangeLim) for i in range(rangeLim)]
    start = time.time()
    mergesort(best)
    stop = time.time()
    tt.append([i,stop-start])

# %% [markdown]
# ## FOR BEST CASE

# %%
tt2 = []
for j in range(100,1000):
    rangeLim2 = j
    best2 = [i for i in range(1,rangeLim2+1)]
    start2 = time.time()
    mergesort(best2)
    stop2 = time.time()
    tt2.append([rangeLim2,stop2-start2])

# %%
plt.title("Merge Sort (Best)")
plt.plot([i[0] for i in tt2],[i[1] for i in tt2])
plt.show()

# %% [markdown]
# ## FOR WORST CASE

# %%
tt3 = []
for k in range(100,1000):
    rangeLim3 = k
    best3 = [i for i in range(1,rangeLim3+1)]
    best3 = best3[::-1]
    start3 = time.time()
    mergesort(best3)
    stop3 = time.time()
    tt3.append([rangeLim3,stop3-start3])

# %%
plt.title("Merge Sort (Worst)")
plt.plot([i[0] for i in tt3],[i[1] for i in tt3])
plt.show()

# %% [markdown]
# Table : Time Complexity of Merge Sort
#
# <table>
# <thead>
# <tr>
# <th>Algorithm</th>
# <th>Time Complexity(Best)</th>
# <th>Time Complexity(Worst)</th>
# <th>Time Complexity(Avg)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Merge Sort</td>
# <td>O(nlogn)</td>
# <td>O(nlogn)</td>
# <td>O(nlogn)</td>
# </tr>
# </tbody>
# </table>
#
# ## Conclusion
#
# From the above graph we can conclude that the time complexity of merge sort is O(nlogn) for all the cases. The time complexity of merge sort is less than the time complexity of bubble sort and insertion sort. Merge sort is a divide and conquer algorithm. It divides the input array into two halves, calls itself for the two halves, and then merges the two sorted halves. The merge() function is used for merging two halves. The merge(arr, l, m, r) is key process that assumes that arr[l..m] and arr[m+1..r] are sorted and merges the two sorted sub-arrays into one. See following C implementation for details.
